# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# new
from imutils.object_detection import non_max_suppression
from imutils import paths
import imutils

# %%
# initialize the HOG descriptor/person detector
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

image = cv2.imread('images/pedestrians01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
orig = image.copy()

plt.figure(figsize=(20,10))

plt.subplot(1,2,1), plt.imshow(orig)
plt.title('Before NMS'),plt.axis("off")


image = imutils.resize(image, width=min(400, image.shape[1]))
#orig = image.copy()

# detect people in the image
(rects, weights) = hog.detectMultiScale(image, winStride=(4, 4),
padding=(8, 8), scale=1.05)
 
# draw the original bounding boxes
for (x, y, w, h) in rects:
    cv2.rectangle(orig, (x, y), (x + w, y + h), (0, 0, 255), 2)

# apply non-maxima suppression to the bounding boxes using a
# fairly large overlap threshold to try to maintain overlapping
# boxes that are still people
rects = np.array([[x, y, x + w, y + h] for (x, y, w, h) in rects])
pick = non_max_suppression(rects, probs=None, overlapThresh=0.65)
 
# draw the final bounding boxes
for (xA, yA, xB, yB) in pick:
    cv2.rectangle(image, (xA, yA), (xB, yB), (0, 255, 0), 2)
    


plt.subplot(1,2,2), plt.imshow(image)
plt.title('After NMS'),plt.axis("off")

plt.show()

# %%
# initialize the HOG descriptor/person detector
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

image = cv2.imread('images/pedestrian.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
orig = image.copy()

plt.figure(figsize=(20,10))

plt.subplot(1,2,1), plt.imshow(orig)
plt.title('Before NMS'),plt.axis("off")


image = imutils.resize(image, width=min(400, image.shape[1]))
#orig = image.copy()

# detect people in the image
(rects, weights) = hog.detectMultiScale(image, winStride=(4, 4),
padding=(8, 8), scale=1.05)
 
# draw the original bounding boxes
for (x, y, w, h) in rects:
    cv2.rectangle(orig, (x, y), (x + w, y + h), (0, 0, 255), 2)

# apply non-maxima suppression to the bounding boxes using a
# fairly large overlap threshold to try to maintain overlapping
# boxes that are still people
rects = np.array([[x, y, x + w, y + h] for (x, y, w, h) in rects])
pick = non_max_suppression(rects, probs=None, overlapThresh=0.65)
 
# draw the final bounding boxes
for (xA, yA, xB, yB) in pick:
    cv2.rectangle(image, (xA, yA), (xB, yB), (0, 255, 0), 2)
    


plt.subplot(1,2,2), plt.imshow(image)
plt.title('After NMS'),plt.axis("off")

plt.show()

# %%
# initialize the HOG descriptor/person detector
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

image = cv2.imread('images/japan_ped.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
orig = image.copy()

plt.figure(figsize=(20,10))

plt.subplot(1,2,1), plt.imshow(orig)
plt.title('Before NMS'),plt.axis("off")


image = imutils.resize(image, width=min(400, image.shape[1]))
#orig = image.copy()

# detect people in the image
(rects, weights) = hog.detectMultiScale(image, winStride=(4, 4),
padding=(8, 8), scale=1.05)
 
# draw the original bounding boxes
for (x, y, w, h) in rects:
    cv2.rectangle(orig, (x, y), (x + w, y + h), (0, 0, 255), 2)

# apply non-maxima suppression to the bounding boxes using a
# fairly large overlap threshold to try to maintain overlapping
# boxes that are still people
rects = np.array([[x, y, x + w, y + h] for (x, y, w, h) in rects])
pick = non_max_suppression(rects, probs=None, overlapThresh=0.65)
 
# draw the final bounding boxes
for (xA, yA, xB, yB) in pick:
    cv2.rectangle(image, (xA, yA), (xB, yB), (0, 255, 0), 2)
    


plt.subplot(1,2,2), plt.imshow(image)
plt.title('After NMS'),plt.axis("off")

plt.show()
