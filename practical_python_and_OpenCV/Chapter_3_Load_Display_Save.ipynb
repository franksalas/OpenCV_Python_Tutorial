# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **load an image:**
# ```python
# img = cv2.imread('images/trex.png')
# ```
#
# **Clone the image and change from BGR to RGB**:
# ```python=
# img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ```
# **figsize, w,h tuple in inches:**
# ```python
#     plt.figure(figsize=(20,10))
# ```
# **subplot 1 row with two images, add a title and remove the x,y ticks:**
# ```python
#     plt.subplot(1,2,1), plt.imshow(img)  # (1 row, 2 ithems, # ithem)
#     plt.title('BGR'),plt.axis("off")
#
#     plt.subplot(1,2,2), plt.imshow(img2)
#     plt.title('RGB'),plt.axis("off")
# ```
#
# **finally show the plot:**
# ```python
#     plt.show()
#    ```

# %%
img = cv2.imread('images/trex.png')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)



plt.figure(figsize=(20,10))

plt.subplot(1,2,1), plt.imshow(img)
plt.title('BGR'),plt.axis("off")

plt.subplot(1,2,2), plt.imshow(img2)
plt.title('RGB'),plt.axis("off")

plt.show()

# %% [markdown]
# ---
# **Get the width in pixels**:
# ```python
#     img.shape[1]
# ```
# **Get the height in pixels**:
# ```python
#     img.shape[0]
#     ```
#
# **Get the channels**:
# ```python
#     img.shape[2]
#     ```
# ---
# ```python
# print("width: {} pixels".format(img.shape[1]))
# print("height: {} pixels".format(img.shape[0]))
# print("channels: {} pixels".format(img.shape[2]))
#
# ```

# %%
print("width:    {} pixels".format(img.shape[1]))
print("height:   {} pixels".format(img.shape[0]))
print("channels:   {} pixels".format(img.shape[2]))
# Out:
# width:    350 pixels
# height:   228 pixels
# channels:   3 pixels
